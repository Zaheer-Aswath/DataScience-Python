# %% [markdown]
# <a href="https://colab.research.google.com/github/Zaheer-Aswath/DataScience-Python/blob/main/Edureka/mohammed_zaheer_day15_diy_solution_doc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Q1. Problem Statement: Data Grouping - I**
#
# Load the “big_bang_theory.csv” dataset provided on LMS into a DataFrame, group the data based on column "directed_by" using the groupby() function and the grouped DataFrame. Now also print all the episodes and the data associated with them, which belongs to the director - Mark Cendroski.

# %%
import pandas as pd

df = pd.read_csv("big_bang_theory_episodes.csv")
#display(df)

#Applying groupby() function to group the data on "directed_by" column.

df1 = df.groupby("directed_by")
print("\n1. Printing the first group from grouped DataFrame: ")
display(df1.first()) #.first() --> used to view result in formed groups

#applying get_group() function on df1 to filter column values("Mark Cendrowski") from column name("directed_by")

print("\n2. Displaying the group related to director- Mark Cendrowski: ")
df2 = df1.get_group("Mark Cendrowski")
display(df2)
# Out:
# 1. Printing the first group from grouped DataFrame:
#                   season  episode_num_in_season  episode_num_overall  \
# directed_by
# Andrew D. Weyman       1                      5                    5
# Anthony Rich           3                     20                   60
# Gay Linvill            7                     16                  151
# Howard Murray          4                     23                   86
# James Burrows          1                      1                    1
# Joel Murray            1                      9                    9
# Kristy Cecil          12                      9                  264
# Mark Cendrowski        1                      2                    2
# Nikki Lorre            9                      7                  190
# Peter Chakos           2                     18                   35
# Ted Wass               1                      8                    8
#
#                                                title  \
# directed_by
# ...

# %% [markdown]
# **Q2. Problem Statement: Data Grouping - II**
#
#
# Load the “big_bang_theory.csv” dataset provided on LMS into a DataFrame; Group the data based on two columns, "directed_by" and "written_by," using the groupby() function and print the grouped DataFrame. Also, print the average viewers in the United States and the director and the writer's details.

# %%
import pandas as pd

df = pd.read_csv("big_bang_theory_episodes.csv")
#display(df)

#Applying groupby() function to group the multiple column "directed_by" and "written_by"

df3 = df.groupby(["directed_by","written_by"])["us_viewers"].mean()
print("\n",df3)
# Out:
#  directed_by       written_by
# Andrew D. Weyman  Story by: Jennifer GlickmanTeleplay by: Dave Goetsch & Steven Molaro                                                  8810000.0
# Anthony Rich      Chuck Lorre & Bill Prady & Lee Aronsohn & Steven Molaro                                                              11630000.0
#                   Story by: Bill Prady & Eric Kaplan & Jim ReynoldsTeleplay by: Steven Molaro & Dave Goetsch & Steve Holland           17730000.0
#                   Story by: Chuck Lorre & Bill Prady & Dave GoetschTeleplay by: Lee Aronsohn & Steven Molaro & Steve Holland           13630000.0
#                   Story by: Chuck Lorre & Bill Prady & Steve HollandTeleplay by: Steven Molaro & Eric Kaplan & Anthony Del Broccolo    14020000.0
#                                                                                                                                           ...
# ...
