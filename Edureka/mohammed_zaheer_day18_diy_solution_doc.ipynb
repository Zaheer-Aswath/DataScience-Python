# %% [markdown]
# <a href="https://colab.research.google.com/github/Zaheer-Aswath/DataScience-Python/blob/main/Edureka/mohammed_zaheer_day18_diy_solution_doc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Q1. Problem Statement: Web Scrapping using BeautifulSoup**
#
# Write a Python program that can extract the data from a website using web scrapping concepts to perform the following tasks:
#
# 1. Use the request library and the link to extract the data.
#
# 2. Use BeautifulSoup to prepare the website's source code, then try to find a table on the source page.
#
# 3. After finding the table, extract data from all available columns and store it in the dataframe.
#
# **Website Link:**
#
# Use the below link to get the data from the table on the website.
#
# https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population

# %%
#Step - 1: Importing Libraries

import requests # requests for performing your HTTP requests to fetch web content.
from bs4 import BeautifulSoup # BeautifulSoup4 for wrangling HTML content as per your requirements.
import pandas as pd

#Step - 2: Get data(scrapping table) from the website link(url) provided, through requests library:

web=requests.get("https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population")
#print(web.status_code)  # status code 200(HTTP Status Codes) defines success - OK

#Step - 3: Beautiful Soup is a Python library for parsing structured data and makes it easy to scrape information from web page

soup=BeautifulSoup(web.content,"html.parser")
#print(soup.prettify()) # -> To make the soup content pretty (readable)

#Step - 4: After parsing the data from web, find the element under "table" tag and specify class of the table as well
my_table = soup.find("table",{"class":"wikitable sortable"})
#my_table

#Step - 5: Once table is found, extract all the rows from the table using findAll function which will return a list of all available <tr> in the table
table = my_table.findAll("tr")

#Step - 6: Declare a variable to store the table rows data as list of lists(rows)
data_need=[]

#Step - 7: Now, as per the table in website,
  #the first tr row ( i.e., 0th index) of table is available under <thead> which contains column names of the table. We will use this later, while creating dataframe
  #the second tr row ( i.e., 1st index) of table contains the world data, hence we will ignore that and concentrate only on individual countries data
  #Individual countries data are available from third row of the table onwards( i.e., 2nd index), hence iterating the table data from 2nd index
for row in table[2:]:

    #Step - 7.1:  for each row, gathering all the data under <td> tag using list comprehension
    data = [i.text.strip() for i in row.find_all('td')]

    #Step - 7.2: We will ignore the last column as it is not required
    data.pop()

    #Step - 7.3: Now, serial numbers in the table (first column) are placed under <th> tag,
      #Hence extracting that separately and inserting it in the row data's list 0th position(since it is first column)
    data.insert(0,row.find('th').text.strip())

    #print(row.find('th').text)
    #print(data)

    #Step - 7.4: Appending each record's data list to the main list
    data_need.append(data)

#print(data_need)

#Step - 8: To print the values from the main list in comma separated format as mentioned in DIY exercise
for row in data_need:
  for value in row:
    print(value,end=", ")
  print("\n")

#Step - 9: To display as DF with column names
  #As already mentioned, Column names are stored in 0th record of table inside th (table header) tag, hence using list comprehension to extract all header values
column_names = [d.text.strip() for d in table[0].find_all('th')]

  #Removing last column header since we removed last column data in Step - 7.2
column_names.pop()

#print(column_names)

#Create dataframe from the list of lists created in Step 7 and column names found above
df=pd.DataFrame(data_need, columns=column_names)
display(df)

#We can also store this dataframe to excel/csv as required
#df.to_csv("Countries_Population_Wiki.csv", index=False)
# Out:
# 1, China, 1,411,750,000, 17.5%, 31 Dec 2022, Official estimate[4],
#
# 2, India, 1,392,329,000, 17.3%, 1 Mar 2023, Official projection[5],
#
# 3, United States, 335,141,000, 4.2%, 28 Jul 2023, National population clock[7],
#
# 4, Indonesia, 277,749,853, 3.5%, 31 Dec 2022, Official estimate[8],
#
# 5, Pakistan, 220,425,254, 2.7%, 1 Jul 2020, Official projection[9],
#
# 6, Nigeria, 216,783,400, 2.7%, 21 Mar 2022, Official projection[10],
#
# 7, Brazil, 203,062,512, 2.5%, 1 Aug 2022, 2022 census result[11],
#
# 8, Bangladesh, 169,828,911, 2.1%, 15 Jun 2022, 2022 census result[12],
#
# 9, Russia, 146,424,729, 1.8%, 1 Jan 2023, Official estimate[13],
#
# 10, Mexico, 129,035,733, 1.6%, 31 Mar 2023, National quarterly estimate[14],
#
# 11, Japan, 124,500,000, 1.5%, 1 May 2023, Official estimate[15],
#
# 12, Philippines, 110,659,000, 1.4%, 28 Jul 2023, National population clock[16],
#
# 13, Ethiopia, 105,163,988, 1.3%, 1 Jul 2022, National annual projection[17],
#
# 14, Egypt, 102,060,688, 1.3%, 1 Jul 2021, Official estimate[18],
#
# 15, Vietnam, 100,000,000, 1.2%, Apr 2023, Official estimate[19],
#
# 16, DR Congo, 95,370,000, 1.2%, 1 Jul 2019, Official figure[20],
#
# 17, Turkey, 85,279,553, 1.1%, 31 Dec 2022, Official estimate[21],
#
# 18, Iran, 85,179,600, 1.1%, 28 Jul 2023, National population clock[22],
#
# 19, Germany, 84,358,845, 1.0%, 31 Dec 2022, National quarterly estimate[23],
#
# 20, Thailand, 68,263,022, 0.8%, 1 Jul 2021, Official estimate[24],
#
# 21, France, 68,128,000, 0.8%, 1 Jul 2023, Monthly national estimate[25],
#
# 22, United Kingdom, 67,026,292, 0.8%, 30 Jun 2021, Official estimate[26],
#
# 23, Tanzania, 61,741,120, 0.8%, 23 Aug 2022, 2022 census result[27],
#
# 24, South Africa, 60,604,992, 0.8%, 1 Jul 2022, Official estimate[28],
#
# 25, Italy, 58,788,924, 0.7%, 30 Apr 2023, Monthly national estimate[29],
#
# 26, Myanmar, 55,770,232, 0.7%, 1 Jul 2022, National annual projection[30],
#
# 27, Colombia, 52,215,503, 0.6%, 30 Jun 2023, Official projection[31],
#
# 28, Kenya, 51,526,000, 0.6%, 1 Jan 2023, Official projection[32],
#
# 29, South Korea, 51,439,038, 0.6%, 31 Dec 2022, Official estimate[33],
#
# 30, Spain, 48,196,693, 0.6%, 1 Apr 2023, Official estimate[34],
#
# 31, Argentina, 46,044,703, 0.6%, 18 May 2022, 2022 census result[35],
#
# 32, Algeria, 45,400,000, 0.6%, 1 Jan 2022, Official estimate[36],
#
# 33, Iraq, 43,324,000, 0.5%, 1 Jul 2023, Official estimate[37],
#
# 34, Uganda, 42,885,900, 0.5%, 1 Jul 2021, Official projection[38],
#
# 35, Sudan, 41,984,500, 0.5%, 1 Jul 2018, Official projection[39],
#
# 36, Ukraine, 41,130,432, 0.5%, 1 Feb 2022, National monthly estimate[40],
#
# 37, Canada, 40,188,800, 0.5%, 28 Jul 2023, National population clock[41],
#
# 38, Poland, 37,726,000, 0.5%, 31 Mar 2023, National monthly estimate[42],
#
# 39, Morocco, 37,047,700, 0.5%, 28 Jul 2023, National population clock[43],
#
# 40, Uzbekistan, 36,197,788, 0.4%, 1 Apr 2023, National quarterly estimate[44],
#
# 41, Afghanistan, 34,262,840, 0.4%, 1 Jan 2023, Official estimate[45],
#
# 42, Peru, 33,396,698, 0.4%, 1 Jul 2022, National annual projection[46],
#
# 43, Angola, 33,086,278, 0.4%, 30 Jun 2022, National annual projection[47],
#
# 44, Malaysia, 32,700,100, 0.4%, 28 Jul 2023, National population clock[48],
#
# 45, Mozambique, 32,419,747, 0.4%, 1 Jul 2022, National annual projection[49],
#
# 46, Saudi Arabia, 32,175,224, 0.4%, 10 May 2022, 2022 census result[50],
#
# 47, Yemen, 31,890,000, 0.4%, 1 Jul 2022, Official estimate[51],
#
# 48, Ghana, 30,832,019, 0.4%, 27 Jun 2021, 2021 census result[52],
#
# 49, Ivory Coast, 29,389,150, 0.4%, 14 Dec 2021, 2021 census result[53],
#
# 50, Nepal, 29,164,578, 0.4%, 25 Nov 2021, 2021 census result[54],
#
# 51, Venezuela, 28,302,000, 0.4%, 30 Jun 2019, Official projection[55],
#
# 52, Madagascar, 26,923,353, 0.3%, 1 Jul 2021, National annual projection[56],
#
# 53, Australia, 26,653,400, 0.3%, 28 Jul 2023, National population clock[57],
#
# 54, North Korea, 25,660,000, 0.3%, 1 Jul 2021, National annual projection[58],
#
# 55, Cameroon, 24,348,251, 0.3%, 1 Jul 2019, National annual projection[59],
#
# 56, Niger, 24,112,753, 0.3%, 1 Jul 2021, National annual projection[60],
#
# –, Taiwan, 23,347,374, 0.3%, 30 Apr 2023, Official estimate[61],
#
# 57, Mali, 23,293,699, 0.3%, 1 Jul 2023, UN projection[3],
#
# 58, Syria, 22,923,000, 0.3%, 1 Jul 2021, Official estimate[62],
#
# 59, Burkina Faso, 22,185,654, 0.3%, 1 Jul 2022, National projection[63],
#
# 60, Sri Lanka, 22,181,000, 0.3%, 1 Jul 2022, Official estimate[64],
#
# 61, Malawi, 21,507,723, 0.3%, 1 Jul 2022, National annual projection[65],
#
# 62, Chile, 19,960,889, 0.2%, 30 Jun 2023, National annual projection[66],
#
# 63, Kazakhstan, 19,854,083, 0.2%, 1 May 2023, National quarterly estimate[67],
#
# 64, Zambia, 19,610,769, 0.2%, 14 Sep 2022, 2022 census result[68],
#
# 65, Romania, 19,053,815, 0.2%, 17 Jul 2022, 2022 census result[69],
#
# 66, Ecuador, 18,336,800, 0.2%, 28 Jul 2023, National population clock[70],
#
# 67, Netherlands, 17,884,800, 0.2%, 28 Jul 2023, National population clock[71],
#
# 68, Somalia, 17,598,000, 0.2%, 1 Jan 2014, Authorized survey[72],
#
# 69, Senegal, 17,223,497, 0.2%, 1 Jul 2021, National annual projection[73],
#
# 70, Guatemala, 17,109,746, 0.2%, 1 Jul 2021, National annual projection[74],
#
# 71, Chad, 16,818,391, 0.2%, 1 Jul 2021, National annual projection[75],
#
# 72, Cambodia, 15,552,211, 0.2%, 3 Mar 2019, 2019 census result[76],
#
# 73, Zimbabwe, 15,178,979, 0.2%, 20 Apr 2022, 2022 census result[77],
#
# 74, Guinea, 13,261,638, 0.2%, 1 Jul 2022, National annual projection[78],
#
# 75, South Sudan, 13,249,924, 0.2%, 1 Jul 2020, National annual projection[79],
#
# 76, Rwanda, 13,246,394, 0.2%, 15 Aug 2022,
#
# 77, Burundi, 12,837,740, 0.2%, 1 Jul 2022, National annual projection[81],
#
# 78, Benin, 12,606,998, 0.2%, 1 Jul 2023, National annual projection[82],
#
# 79, Bolivia, 12,006,031, 0.1%, 1 Jul 2022, National annual projection[83],
#
# 80, Tunisia, 11,803,588, 0.1%, 1 Jan 2022, National estimate[84],
#
# 81, Papua New Guinea, 11,781,559, 0.1%, 1 Jul 2021, National estimate[85],
#
# 82, Belgium, 11,755,313, 0.1%, 1 Apr 2023, Official estimate[86],
#
# 83, Haiti, 11,743,017, 0.1%, 1 Jul 2020, National annual projection[87],
#
# 84, Jordan, 11,442,600, 0.1%, 28 Jul 2023, National population clock[88],
#
# 85, Cuba, 11,089,511, 0.1%, 31 Dec 2022, Official estimate[89],
#
# 86, Czech Republic, 10,827,529, 0.1%, 1 Jan 2023, Official estimate[90],
#
# 87, Sweden, 10,538,026, 0.1%, 30 Apr 2023, Monthly national estimate[91],
#
# 88, Dominican Republic, 10,535,535, 0.1%, 1 Jul 2021, National annual projection[92],
#
# 89, Greece, 10,482,487, 0.1%, 23 Nov 2021, 2021 census result[93],
#
# 90, Portugal, 10,467,366, 0.1%, 31 Dec 2022, 2022 estimate[94],
#
# 91, Azerbaijan, 10,135,373, 0.1%, 1 Mar 2023, Monthly national estimate[95],
#
# 92, Israel, 9,741,000, 0.1%, 1 May 2023, National monthly estimate[96],
#
# 93, Hungary, 9,597,085, 0.1%, 1 Jan 2023, Official estimate[97],
#
# 94, Honduras, 9,546,178, 0.1%, 1 Jul 2021, National annual projection[98],
#
# 95, Tajikistan, 9,506,000, 0.1%, 1 Jan 2021, Official estimate[99],
#
# 96, United Arab Emirates, 9,282,410, 0.1%, 31 Dec 2020, Official estimate[100],
#
# 97, Belarus, 9,200,617, 0.1%, 1 Jan 2023, Official estimate[101],
#
# 98, Austria, 9,120,091, 0.1%, 1 Apr 2023, National quarterly estimate[102],
#
# 99, Switzerland, 8,865,270, 0.1%, 31 Mar 2023, National quarterly estimate[103],
#
# 100, Sierra Leone, 8,494,260, 0.1%, 1 Jul 2022, National annual projection[104],
#
# 101, Togo, 8,095,498, 0.1%, 8 Nov 2022, 2022 census result[105],
#
# 102, Paraguay, 7,453,695, 0.09%, 1 Jul 2022, National annual projection[106],
#
# 103, Laos, 7,337,783, 0.09%, 1 Jul 2021, National annual projection[107],
#
# –, Hong Kong (China), 7,333,200, 0.09%, 31 Dec 2022, National estimate[108],
#
# 104, Kyrgyzstan, 7,100,000, 0.09%, 1 Mar 2023, Monthly national estimate[109],
#
# 105, Libya, 6,931,061, 0.09%, 1 Jan 2020, Official estimate[110],
#
# 106, El Salvador, 6,884,888, 0.09%, 1 Jul 2022, National annual projection[111],
#
# 107, Serbia, 6,647,003, 0.08%, 31 Oct 2022, 2022 census result[112],
#
# 108, Nicaragua, 6,595,674, 0.08%, 30 Jun 2020, Official estimate[113],
#
# 109, Turkmenistan, 6,516,100, 0.08%, 1 Jul 2023, UN projection[3],
#
# 110, Bulgaria, 6,447,710, 0.08%, 31 Dec 2022, Official annual estimate[114],
#
# 111, Congo, 6,106,869, 0.08%, 1 Jul 2023, UN projection[3],
#
# 112, Denmark, 5,941,388, 0.07%, 1 Apr 2023, National quarterly estimate[115],
#
# 113, Central African Republic, 5,633,412, 0.07%, 1 Jul 2020, National annual projection[116],
#
# 114, Finland, 5,541,016, 0.07%, 30 Apr 2023, Monthly national estimate[117],
#
# 115, Norway, 5,504,329, 0.07%, 31 Mar 2023, National quarterly estimate[118],
#
# 116, Lebanon, 5,490,000, 0.07%, 1 Jul 2021, Official estimate[119],
#
# 117, Palestine, 5,483,450, 0.07%, 1 Jan 2023, National annual projection[120],
#
# 118, Singapore, 5,453,600, 0.07%, 30 Jun 2022, Official estimate[121],
#
# 119, Slovakia, 5,426,857, 0.07%, 31 Mar 2023, National quarterly estimate[122],
#
# 120, Costa Rica, 5,213,362, 0.06%, 30 Jun 2022, National annual projection[123],
#
# 121, New Zealand, 5,199,100, 0.06%, 31 Mar 2023, National quarterly estimate[124],
#
# 122, Ireland, 5,149,139, 0.06%, 3 Apr 2022, 2022 census[125],
#
# 123, Oman, 5,035,658, 0.06%, 30 Apr 2023, Monthly national estimate[126],
#
# 124, Kuwait, 4,670,713, 0.06%, 31 Dec 2020, Official estimate[127],
#
# 125, Liberia, 4,661,010, 0.06%, 1 Jul 2021, National annual projection[128],
#
# 126, Mauritania, 4,372,037, 0.05%, 1 Jul 2022, National annual projection[129],
#
# 127, Panama, 4,278,500, 0.05%, 1 Jul 2020, National annual projection[130],
#
# 128, Croatia, 3,888,529, 0.05%, 31 Aug 2021, 2021 census[131],
#
# 129, Eritrea, 3,748,902, 0.05%, 1 Jul 2023, UN projection[3],
#
# 130, Georgia, 3,736,400, 0.05%, 1 Jan 2023, Official estimate[132],
#
# 131, Uruguay, 3,554,915, 0.04%, 30 Jun 2022, National annual projection[133],
#
# 132, Mongolia, 3,457,548, 0.04%, 31 Dec 2022, National annual projection[134],
#
# 133, Bosnia and Herzegovina, 3,277,082, 0.04%, 1 Jul 2022, Official estimate[135][136],
#
# –, Puerto Rico (US), 3,221,789, 0.04%, 1 Jul 2022, Annual projection[137],
#
# 134, Qatar, 3,005,069, 0.04%, 31 Mar 2023, Monthly national estimate[138],
#
# 135, Armenia, 2,981,200, 0.04%, 1 Jan 2023, National quarterly estimate[139],
#
# 136, Lithuania, 2,862,274, 0.04%, 1 May 2023, Monthly national estimate[140],
#
# 137, Jamaica, 2,825,544, 0.04%, 1 Jul 2019, National projection[141],
#
# 138, Albania, 2,793,592, 0.03%, 1 Jan 2022, Official estimate[142],
#
# 139, Moldova, 2,604,000, 0.03%, 1 Jan 2022, Official estimate[143],
#
# 140, Namibia, 2,596,037, 0.03%, 1 Jul 2022, National annual projection[144],
#
# 141, Gambia, 2,417,471, 0.03%, 1 Jul 2022, National projection[145],
#
# 142, Botswana, 2,410,338, 0.03%, 1 Jul 2021, National annual projection[146],
#
# 143, Lesotho, 2,306,000, 0.03%, 1 Jul 2023, Official projection[147],
#
# 144, Gabon, 2,233,272, 0.03%, 1 Jul 2021, National annual projection[148],
#
# 145, Slovenia, 2,116,972, 0.03%, 1 Jan 2023, National quarterly estimate[149],
#
# 146, Latvia, 1,885,400, 0.02%, 1 Apr 2023, Monthly national estimate[150],
#
# 147, North Macedonia, 1,832,696, 0.02%, 1 Nov 2021, 2021 census result[151],
#
# –, Kosovo, 1,798,188, 0.02%, 31 Dec 2020, Official estimate[152],
#
# 148, Guinea-Bissau, 1,781,308, 0.02%, 1 Jul 2023, National annual projection[153],
#
# 149, Equatorial Guinea, 1,558,160, 0.02%, 1 Jul 2022, Official estimate[154],
#
# 150, Bahrain, 1,504,365, 0.02%, 1 Jul 2021, Official estimate[155],
#
# 151, Estonia, 1,365,884, 0.02%, 1 Jan 2023, Official estimate[156],
#
# 152, Trinidad and Tobago, 1,365,805, 0.02%, 30 Jun 2022, Official estimate[157],
#
# 153, East Timor, 1,336,222, 0.02%, 1 Jul 2022, National annual projection[158],
#
# 154, Mauritius, 1,261,196, 0.02%, 31 Dec 2022, National estimate[159],
#
# 155, Eswatini, 1,223,362, 0.02%, 1 Jul 2023, Official projection[160],
#
# 156, Djibouti, 1,001,454, 0.01%, 1 Jul 2022, National projection [161],
#
# 157, Cyprus, 918,100, 0.01%, 1 Oct 2021, 2021 census result[162],
#
# 158, Fiji, 893,468, 0.01%, 1 Jul 2021, National annual projection[163],
#
# 159, Bhutan, 763,200, 0.009%, 30 May 2022, National annual projection[164],
#
# 160, Comoros, 758,316, 0.009%, 15 Dec 2017, 2017 census result[165],
#
# 161, Guyana, 743,699, 0.009%, 1 Jul 2019, Official estimate[166],
#
# 162, Solomon Islands, 728,041, 0.009%, 1 Jul 2021, National annual projection[167],
#
# –, Macau (China), 673,600, 0.008%, 31 Mar 2023, National quarterly estimate[168],
#
# 163, Luxembourg, 660,809, 0.008%, 1 Jan 2023, Official estimate[169],
#
# 164, Montenegro, 617,683, 0.008%, 1 Jan 2022, National annual estimate[170],
#
# 165, Suriname, 616,500, 0.008%, 1 Jul 2021, Official estimate[171],
#
# –, Western Sahara, 587,259, 0.007%, 1 Jul 2023, UN projection[3],
#
# 166, Cape Verde, 569,509, 0.007%, 1 Jul 2022, National annual projection[172],
#
# 167, Malta, 519,562, 0.006%, 21 Nov 2021, 2021 census result[173],
#
# 168, Belize, 441,471, 0.005%, 1 Jul 2022, Official estimate[174],
#
# 169, Brunei, 440,715, 0.005%, 1 Jul 2021, Official estimate[175],
#
# 170, Maldives, 397,372, 0.005%, 31 Dec 2021, Official estimate[176],
#
# 171, Bahamas, 397,360, 0.005%, 1 Jul 2022, National annual projection| [177],
#
# 172, Iceland, 394,200, 0.005%, 1 Jul 2023, National quarterly estimate[178],
#
# –, Northern Cyprus, 382,836, 0.005%, 31 Dec 2020, Official estimate[179],
#
# –, Transnistria, 360,938, 0.004%, 31 Dec 2022, Official estimate[180],
#
# 173, Vanuatu, 301,295, 0.004%, 1 Jul 2021, National annual projection[167],
#
# –, French Polynesia (France), 279,890, 0.003%, 1 Jul 2021, National annual projection[167],
#
# –, New Caledonia (France), 273,674, 0.003%, 1 Jul 2021, National annual projection[167],
#
# 174, Barbados, 267,800, 0.003%, 31 Dec 2022, Official estimate| [181],
#
# –, Abkhazia, 245,424, 0.003%, 1 Jan 2020, Official estimate[182],
#
# 175, São Tomé and Príncipe, 214,610, 0.003%, 1 Jul 2021, National annual projection[183],
#
# 176, Samoa, 205,557, 0.003%, 6 Nov 2021, Census 2021[184],
#
# 177, Saint Lucia, 178,696, 0.002%, 1 Jul 2018, Official estimate[185],
#
# –, Guam (US), 153,836, 0.002%, 1 Apr 2020, 2020 census result[186],
#
# –, Curacao (Netherlands), 148,925, 0.002%, 1 Jan 2023, Official estimate[187],
#
# –, Artsakh, 148,900, 0.002%, 1 Oct 2019, Official estimate[188],
#
# 178, Kiribati, 120,740, 0.001%, 1 Jul 2021, National annual projection[167],
#
# 179, Grenada, 112,579, 0.001%, 1 Jul 2019, Official estimate[189],
#
# 180, Saint Vincent and the Grenadines, 110,872, 0.001%, 1 Jul 2022, Official estimate[190],
#
# –, Jersey (UK), 107,800, 0.001%, 31 Dec 2019, Official estimate[191],
#
# –, Aruba (Netherlands), 106,739, 0.001%, 30 Sep 2022, National quarterly estimate[192],
#
# 181, Micronesia, 105,754, 0.001%, 1 Jul 2021, National annual projection[167],
#
# 182, Antigua and Barbuda, 100,772, 0.001%, 1 Jan 2022, National annual estimate[193],
#
# 183, Seychelles, 100,447, 0.001%, 22 Apr 2022, 2022 Census[194],
#
# 184, Tonga, 100,179, 0.001%, 1 Jan 2022, National annual estimate[195],
#
# –, US Virgin Islands (US), 87,146, 0.001%, 1 Apr 2020, 2020 census result[196],
#
# –, Isle of Man (UK), 84,069, 0.001%, 30 May 2021, 2021 census result[197],
#
# 185, Andorra, 82,623, 0.001%, 30 Apr 2023, Official estimate[198],
#
# –, Cayman Islands (UK), 71,105, 0.0009%, 30 Sep 2020, 2021 Census[199],
#
# 186, Dominica, 67,408, 0.0008%, 31 Dec 2017, Official estimate[200],
#
# –, Bermuda (UK), 64,055, 0.0008%, 1 Jul 2021, National annual projection[201],
#
# –, Guernsey (UK), 63,950, 0.0008%, 30 Jun 2022, National quarterly estimate[202],
#
# –, Greenland (Denmark), 56,609, 0.0007%, 1 Jan 2023, National quarterly estimate[203],
#
# –, South Ossetia, 56,520, 0.0007%, 31 Dec 2021, Official estimate[204],
#
# –, Faroe Islands (Denmark), 54,503, 0.0007%, 1 Jun 2023, Monthly national estimate[205],
#
# –, American Samoa (US), 49,710, 0.0006%, 1 Apr 2020, 2020 census result[206],
#
# 187, Saint Kitts and Nevis, 47,195, 0.0006%, 15 May 2011, 2011 census result[207],
#
# –, Northern Mariana Islands (US), 47,329, 0.0006%, 1 Apr 2020, 2020 census result[208],
#
# –, Turks and Caicos Islands (UK), 46,131, 0.0006%, 1 Jul 2021, Official estimate[209],
#
# –, Sint Maarten (Netherlands), 42,938, 0.0005%, 1 Jan 2023, Official estimate[210],
#
# 188, Liechtenstein, 39,680, 0.0005%, 31 Dec 2022, National estimate[211],
#
# 189, Marshall Islands, 39,262, 0.0005%, 1 Jul 2021, 2021 Census[212],
#
# 190, Monaco, 39,150, 0.0005%, 31 Dec 2021, Official estimate[213],
#
# –, Gibraltar (UK), 34,003, 0.0004%, 1 Jul 2016, Official figure[214],
#
# 191, San Marino, 33,847, 0.0004%, 30 Apr 2023, Monthly national estimate[215],
#
# –, Saint Martin (France), 32,358, 0.0004%, 1 Jan 2020, Official estimate[216],
#
# –, British Virgin Islands (UK), 31,538, 0.0004%, 1 Jul 2023, UN projection[3],
#
# –, Åland (Finland), 30,423, 0.0004%, 30 Apr 2023, Monthly national estimate[117],
#
# 192, Palau, 16,733, 0.0002%, 1 Jul 2021, 2021 Census[217],
#
# –, Anguilla (UK), 15,701, 0.0002%, 31 Dec 2021, Official estimate[218],
#
# –, Cook Islands, 15,040, 0.0002%, 1 Jul 2021, 2021 Census[219],
#
# 193, Nauru, 11,832, 0.0001%, 1 Jul 2021, National annual projection[167],
#
# –, Wallis and Futuna (France), 11,369, 0.0001%, 1 Jan 2021, National annual projection[167],
#
# 194, Tuvalu, 10,679, 0.0001%, 1 Jul 2021, National annual projection[167],
#
# –, Saint Barthélemy (France), 10,585, 0.0001%, 1 Jan 2020, Official estimate[216],
#
# –, Saint Pierre and Miquelon (France), 6,092, 0%, 1 Jan 2020, Official estimate[216],
#
# –, Saint Helena, Ascension and Tristan da Cunha (UK), 5,651, 0%, 1 Jul 2021, 2021 Census[220][221][222],
#
# –, Montserrat (UK), 4,433, 0%, 1 Jul 2022, Official figure[223],
#
# –, Falkland Islands (UK), 3,662, 0%, 10 Oct 2023, 2021 census result[224],
#
# –, Norfolk Island (Australia), 2,188, 0%, 1 Jan 2021, 2021 Census[225],
#
# –, Christmas Island (Australia), 1,692, 0%, 1 Jan 2021, 2021 Census [226],
#
# –, Tokelau (NZ), 1,647, 0%, 1 Jan 2019, 2019 Census [227],
#
# –, Niue, 1,549, 0%, 1 Jul 2021, National annual projection[167],
#
# –, Cocos (Keeling) Islands (Australia), 593, 0%, 30 Jun 2020, 2021 Census[228],
#
# 195, Vatican City, 246, 0%, 26 Jun 2023, Monthly national estimate[229],
#
# –, Pitcairn Islands (UK), 47, 0%, 1 Jul 2021, Official estimate[230],
#                          Country / Dependency     Population % ofworld  \
# 0      1                                China  1,411,750,000     17.5%
# 1      2                                India  1,392,329,000     17.3%
# 2      3                        United States    335,141,000      4.2%
# 3      4                            Indonesia    277,749,853      3.5%
# 4      5                             Pakistan    220,425,254      2.7%
# ..   ...                                  ...            ...       ...
# 236    –                         Tokelau (NZ)          1,647        0%
# 237    –                                 Niue          1,549        0%
# 238    –  Cocos (Keeling) Islands (Australia)            593        0%
# 239  195                         Vatican City            246        0%
# 240    –                Pitcairn Islands (UK)             47        0%
#
#             Date Source (official or fromthe United Nations)
# 0    31 Dec 2022                        Official estimate[4]
# 1     1 Mar 2023                      Official projection[5]
# 2    28 Jul 2023                National population clock[7]
# 3    31 Dec 2022                        Official estimate[8]
# 4     1 Jul 2020                      Official projection[9]
# ..           ...                                         ...
# 236   1 Jan 2019                           2019 Census [227]
# 237   1 Jul 2021             National annual projection[167]
# 238  30 Jun 2020                            2021 Census[228]
# 239  26 Jun 2023              Monthly national estimate[229]
# 240   1 Jul 2021                      Official estimate[230]
#
# [241 rows x 6 columns]
